# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

# %%
def T(kappa,z,t,T0):
    return T0*erf(z/np.sqrt(4*kappa*t))

# %% [markdown]
# ### Temperature with depth, for a few times:

# %%
kappa =1
T0 = 1000 
ts = [1,10,100,1000]
zs = np.linspace(0,100,num=100)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for t in ts:
    ax.plot(T(kappa,zs,t,T0),zs,label='time ='+str(t))
ax.invert_yaxis()
plt.legend()
plt.xlabel('Temperature')
plt.ylabel('Depth')
plt.show()

# %% [markdown]
# ### Temperature as a function of time, for a few depths:

# %%
zs = [1,10,25,100]
ts = np.linspace(0.1,1000,num=100)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for z in zs:
    plt.plot(ts,T(kappa,z,ts,T0),label='depth ='+str(z))
plt.legend()
plt.ylabel('Temperature')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# ###  Cool homework: Plot the slab with isotherms at different times
# And note to self: do it in 2D for subduction problems
