# %% [markdown]
# Let us create a catalogue of events from the GEONET earthquake catalogue.  First, we install obspy (if you do not have it yet), and import the modules we will use:

# %%
# !pip install obspy
# !pip install cartopy 
from obspy.core.event import read_events # obspy event class has a method to read events from a catalogue
from obspy import UTCDateTime # obspy class to handle time 
from obspy.clients.fdsn import Client # object that sets up an FDSN client
# for interactive inline plotting in jupyter:
# %matplotlib notebook
# Out:
# Requirement already satisfied: obspy in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: requests in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (2.28.1)
# Requirement already satisfied: scipy>=1.0.0 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (1.9.3)
# Requirement already satisfied: setuptools in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (65.5.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (1.23.4)
# Requirement already satisfied: lxml in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (4.9.1)
# Requirement already satisfied: decorator in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (5.1.1)
# Requirement already satisfied: sqlalchemy in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (1.4.39)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from obspy) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from matplotlib>=3.2.0->obspy) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from requests->obspy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from requests->obspy) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from requests->obspy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from requests->obspy) (1.26.12)
# Requirement already satisfied: greenlet!=0.4.17 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from sqlalchemy->obspy) (1.1.1)
# Requirement already satisfied: six>=1.5 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->obspy) (1.16.0)
# Requirement already satisfied: cartopy in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (0.19.0.post1)
# Requirement already satisfied: pyshp>=2 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from cartopy) (2.1.3)
# Requirement already satisfied: numpy>=1.13.3 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from cartopy) (1.23.4)
# Requirement already satisfied: shapely>=1.5.6 in /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages (from cartopy) (1.8.4)

# %% [markdown]
# Then we create a client object:

# %%
client=Client("GEONET")

# %% [markdown]
# Define a start and an endtime. UTCDateTime is a functionality to deal with "time" as a float:

# %%
starttime =UTCDateTime("2008-01-01T00:00:00")
endtime= UTCDateTime("2016-10-31T00:00:00")

# %% [markdown]
# Define other search criteria (lat, lon of the search box, and a minimum magnitude of the events):

# %%
minlat=-50
maxlat=-35
minlon=160
maxlon=180
minmag=5.5

# %% [markdown]
# Create a catalogue object that contains all events that match our criteria:

# %%
events = client.get_events(minlatitude=minlat,maxlatitude=maxlat,minlongitude=minlon,maxlongitude=maxlon,starttime=starttime, endtime=endtime,mindepth=50,minmagnitude=minmag)

# %%
print(events)
# Out:
# 6 Event(s) in Catalog:
# 2015-04-24T03:36:42.412330Z | -42.090, +173.068 | 6.23 M  | manual
# 2015-01-13T11:40:00.691341Z | -45.689, +166.869 | 5.75 M  | manual
# 2011-01-27T15:02:46.965000Z | -38.413, +176.006 | 5.6  Mw | manual
# 2012-07-03T10:36:14.209118Z | -40.049, +173.765 | 6.18 M  | manual
# 2012-12-07T18:19:07.412625Z | -38.334, +176.064 | 5.60 M  | manual
# 2013-02-16T05:16:17.016150Z | -36.309, +178.213 | 5.93 MLv | manual

# %% [markdown]
# The catalogue object has a public method called "plot"
# (If this creates two plots for you too, I don't understand that. Seems like a bug to me!)

# %%
events.plot();
# Out:
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:239: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:239: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:385: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /home/kvan637/miniconda3/envs/newobspy/lib/python3.10/site-packages/cartopy/crs.py:385: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
